# %% [markdown]
# **READING THE CSV FILES**

# %%
import pandas as pd     #Dataframe operation
import numpy as np      #math operation
import matplotlib.pyplot as plt    #Diagrams / plots 
import seaborn as sns              #Diagrams / plot

# %%
# data set name: visadataset
# read csv file : Comma separeated value
# extension : .csv
# you can read this using pandas package
# read excel file
# extension: .xlsx

# %%
#path
#file location + file name + extension

path=r"C:\Users\hp\OneDrive\Documents\DATA SCIENCE\PYTHON FILES\Visadataset.csv"

# %%
pd.read_csv(path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path=r"C:\Users\hp\OneDrive\Documents\DATA SCIENCE\PYTHON FILES\bank.csv"

# %%
pd.read_csv(path)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
pd.read_csv(path,
           header=None)
# Out:
#        0              1        2          3        4        5        6     7   \
# 0     age            job  marital  education  default  balance  housing  loan
# 1      30     unemployed  married    primary       no     1787       no    no
# 2      33       services  married  secondary       no     4789      yes   yes
# 3      35     management   single   tertiary       no     1350      yes    no
# 4      30     management  married   tertiary       no     1476      yes   yes
# ...   ...            ...      ...        ...      ...      ...      ...   ...
# 4517   33       services  married  secondary       no     -333      yes    no
# 4518   57  self-employed  married   tertiary      yes    -3313      yes   yes
# 4519   57     technician  married  secondary       no      295       no    no
# 4520   28    blue-collar  married  secondary       no     1137       no    no
# 4521   44   entrepreneur   single   tertiary       no     1136      yes   yes
#
# ...

# %% [markdown]
# **CREATE DATA FRAME USING LIST**

# %%
names=["ramesh","suresh","satish"]
age=[30,40,50]
names,age
# Out:
# (['ramesh', 'suresh', 'satish'], [30, 40, 50])

# %%
pd.DataFrame()       #to make the dataframe
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# *PROVIDE DATA*

# %%
pd.DataFrame(zip(names,age))
# Out:
#         0   1
# 0  ramesh  30
# 1  suresh  40
# 2  satish  50

# %%
#providing the columns 
pd.DataFrame(zip(names,age),columns=["name","age"])
# Out:
#      name  age
# 0  ramesh   30
# 1  suresh   40
# 2  satish   50

# %%
#providing index
pd.DataFrame(zip(names,age),columns=["name","age"],index=['a','b','c'])
# Out:
#      name  age
# a  ramesh   30
# b  suresh   40
# c  satish   50

# %%
df=pd.DataFrame(zip(names,age),columns=["name","age"],index=['a','b','c'])
df
# Out:
#      name  age
# a  ramesh   30
# b  suresh   40
# c  satish   50

# %%
city_names=['hyd','banglore','mumbai']
df['city']=city_names

# %%
df
# Out:
#      name  age      city
# a  ramesh   30       hyd
# b  suresh   40  banglore
# c  satish   50    mumbai

# %% [markdown]
# - if you want to add a new column
# - df['new column']
# - you need to have a list which is having some elements that elements need to equal to number of rows
# - city_names=['Hyd','Blr','Chennai']
# - df['city']=city_names

# %% [markdown]
# $update$ $the$ $exsisting$ $column$

# %% [markdown]
# - if you want to create new column or update the old column both are same way

# %%
df['name']=['hafsa','chunnu','siddu']

city_names=['hyd','banglore','mumbai']
df['city']=city_names
df
# Out:
#      name  age      city
# a   hafsa   30       hyd
# b  chunnu   40  banglore
# c   siddu   50    mumbai

# %% [markdown]
# **DROP THE COLUMN OR UPDATE THE EXISTING ONE**

# %% [markdown]
# - In order to drop the column
# - We need to use drop method
# - It takes 3 parameters
#   - drop column or row
#   - mention the column name
#   - axis
#     - axis=1 reference as column
#     - axis=0 reference as row
# - you want to create a new dataframe or
# - you want overwrite the existing dataframe
#   - inplace= True

# %%
df.drop('city',    #column name
       axis=1,     #column
       inplace=True)  #update the existing data
df
# Out:
#      name  age
# a   hafsa   30
# b  chunnu   40
# c   siddu   50

# %%
df.drop('c',     #row name
       axis=0,   #row
       inplace=True)
df
# Out:
#      name  age
# a   hafsa   30
# b  chunnu   40

# %% [markdown]
# $save$ $the$ $data frame$

# %%
df.to_csv(r"C:\Users\hp\OneDrive\Documents\DATA SCIENCE\PYTHON FILES\output.csv")

# %%
pd.read_csv(r"C:\Users\hp\OneDrive\Documents\DATA SCIENCE\PYTHON FILES\output.csv")
# Out:
#   Unnamed: 0    name  age
# 0          a   hafsa   30
# 1          b  chunnu   40

# %% [markdown]
# - Its considering index as a column
# - To avoid that take index = false

# %%
df.to_csv(r"C:\Users\hp\OneDrive\Documents\DATA SCIENCE\PYTHON FILES\output.csv",index=False)

# %%
pd.read_csv(r"C:\Users\hp\OneDrive\Documents\DATA SCIENCE\PYTHON FILES\output.csv")
# Out:
#      name  age
# 0   hafsa   30
# 1  chunnu   40

# %% [markdown]
# $DATAFARAME$ $CREATION$ $USING$ $DICTIONARY$

# %%
d1={"names": ["ramesh","suresh","satish"],
    "age":[30,40,50]}
pd.DataFrame(d1)
# Out:
#     names  age
# 0  ramesh   30
# 1  suresh   40
# 2  satish   50

# %%
ndf=pd.DataFrame(d1,index=['a','b','c'])

# %%
st_marks=[100,98,77]
d1['Marks']=st_marks
ndf
# Out:
#     names  age  Marks
# a  ramesh   30    100
# b  suresh   40     98
# c  satish   50     77

# %%
ndf.drop('age',
        axis=1,
        inplace=True)

# %%
ndf
# Out:
#     names  Marks
# a  ramesh    100
# b  suresh     98
# c  satish     77

# %%
ndf.to_csv(r"C:\Users\hp\OneDrive\Documents\DATA SCIENCE\PYTHON FILES\mycreation.csv",index=False)

# %%
pd.read_csv(r"C:\Users\hp\OneDrive\Documents\DATA SCIENCE\PYTHON FILES\mycreation.csv")
# Out:
#     names  Marks
# 0  ramesh    100
# 1  suresh     98
# 2  satish     77
